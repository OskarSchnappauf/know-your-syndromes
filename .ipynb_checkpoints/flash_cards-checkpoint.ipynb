# %%
import docx
doc = docx.Document('/Users/oskar/Python/small_projects/Syndromes_Flash_Cards/Test.docx')
all_paras = doc.paragraphs
syndromes = []
subheadings = []
body = []
for paragraph in doc.paragraphs:
    #print(paragraph.style)
    if paragraph.style.name=='Heading':
        syndromes.append(paragraph.text)
    elif paragraph.style.name=='Heading 2':
        subheadings.append(paragraph.text)
    elif paragraph.style.name=='Body A':
        body.append(paragraph.text)

# %%
class Syndromes:
  def __init__(self, name, genetics, clinical_findings, etiology, pathogenesis, genetic_testing, others):
    self.name = name
    self.genetics = genetics
    self.clinical_findings = clinical_findings
    self.etiology = etiology
    self.pathogenesis = pathogenesis
    self.genetic_testing = genetic_testing
    self.others = others

# %%
from docx import Document

def is_heading(paragraph):
    """Checks if a paragraph is a heading.

    :param paragraph:
    :return:
    """
    if paragraph.style.name=='Heading':
        return True


def iterate_document_sections(document):
    """For each headed section, generate a sequence of paragraphs.
    Each sequence starts with a headed paragraph, followed by text paragraphs.

    :param document: Current Comet Issue
    :return: an article
    """
    paragraphs = [document.paragraphs[0]]
    for paragraph in document.paragraphs[1:]:
        if is_heading(paragraph):
            yield paragraphs
            paragraphs = [paragraph]
            continue
        paragraphs.append(paragraph)
    yield paragraphs


def create_document_from_paragraphs(paragraphs):
    """Iterates through the paragraphs containing articles and splits them into separate files.

    :param paragraphs: Article text
    :return: New document with a single article.
    """
    new_doc = Document()
    for counter, words in enumerate(paragraphs):
        new_content = words.text
        new_doc.add_paragraph(new_content)
    syndrome_name.append(new_doc.paragraphs[0].text)
    #information = []
    #for para in new_doc.paragraphs[1:]:
    #    information.append((para.text))
    #information_all.append(information)
        
    #new_doc.save('/Users/oskar/Python/small_projects/Syndromes_Flash_Cards/separated/' + str(counter) + '.docx')
    
document = docx.Document('/Users/oskar/Python/small_projects/Syndromes_Flash_Cards/Test.docx')
for paragraphs in iterate_document_sections(document):
    create_document_from_paragraphs(paragraphs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-883dd38ec28f> in <module>
#      45 for paragraphs in iterate_document_sections(document):
#      46     create_document_from_paragraphs(paragraphs)
# ---> 47     syndrome_name.append(new_doc.paragraphs[0].text)
#      48     information = []
#      49     for para in new_doc.paragraphs[1:]:
#
# NameError: name 'new_doc' is not defined

# %%
syndrome_name
# Out:
# ['Brugada Syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  'Alagille syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
#  '22q11.2 deletion syndrome/DiGeorge/Velocardiofacial syndrome',
# ...

# %%
doc = docx.Document('/Users/oskar/Python/small_projects/Syndromes_Flash_Cards/test19.docx')

# %%
all_paras = doc.paragraphs
syndromes = []
subheadings = []
body = []
for paragraph in doc.paragraphs:
    #print(paragraph.style)
    if paragraph.style.name=='Heading':
        syndromes.append(paragraph.text)
    elif paragraph.style.name=='Heading 2':
        subheadings.append(paragraph.text)
    elif paragraph.style.name=='Body A':
        body.append(paragraph.text)

# %%
from docx import Document
import re
document = Document('/Users/oskar/Python/small_projects/Syndromes_Flash_Cards/separated/test22.docx')
syndrome_name = document.paragraphs[0].text
information = []
for para in document.paragraphs[1:]:
    information.append(para.text)
information_joined = ', '.join(information)
re.split('Genetics, |Clinical findings/Dysmorphic features, |Etiology, |Pathogenesis, |Others,',information_joined)
# Out:
# ['',
#  '-Deletion of ~3Mb on 22q11.2; NAHR, -AD, 90-95% de novo, -males = females, -complete penetrance, ',
#  '-Congenital heart disease (74% of individuals; particularly conotruncal defects, TOF), -Palatal abnormalities (69%), -Learning difficulties (70%-90%), -Thymus hypo/aplasia  Immune deficiency (77%), -Parathyroid hypo/aplasia  Hypocalcemia, -Facial: micrognathia, ear anomalies, cleft palate, short palpebral fissures, short upper lip, ',
#  '-Prevalence 1:3000, ',
#  '-Deleted region is flanked by low copy number repeats (LCRs), -Contains TBX1, responsible for phenotype, Genetic testing, -FISH, MLPA, CMA; 5% with normal test result on FISH, ',
#  ' -most common microdeletion syndrome, -22q11.2 duplication syndrome with same region: normal to intellectual disability/learning disability, delayed psychomotor development, growth retardation, and/or hypotonia']

# %%
from docx import Document
import re
import pandas as pd
syndrome_name = []
information_all = []
for name in glob.glob('/Users/oskar/Python/small_projects/Syndromes_Flash_Cards/separated/*.docx'):
    document = Document(name)
    syndrome_name.append(document.paragraphs[0].text)
    information = []
    for para in document.paragraphs[1:]:
        information.append((para.text))
    information_all.append(information)

# %%
information_all

# %%
information_final = []
for element in information_all:
    information_final.append(re.split('Genetics, |Clinical findings/Dysmorphic features, |Etiology, |Pathogenesis, |Others,',', '.join(element)))
information_final
# Out:
# [['',
#   '-Most common SCN5A (3p21; 15-30%), also 22 other genes (<1%), -AD, except KCNE5 (XLR), ',
#   '-ST-segment abnormalities in leads V1-V3 on electrocardiogram, -Syncope (temporary loss of consciousness), -Nocturnal agonal respiration, -High risk of ventricular arrhythmias and sudden death, -Mainly during adulthood (2 days to 85 yrs), mean age of sudden death: 40 yrs, -May present as SIDS or sudden unexpected nocturnal death syndrome (SUNDS), ',
#   '-Prevalence of the disease in endemic areas is on the order of 1:2,000, ',
#   '-SCN5A encodes the α-subunit of the cardiac sodium channel and is responsible for phase 0 of the cardiac action potential, -Pathogenic variants in SCN5A result in a decrease in Na+ current  lack of expression of the mutated channel or accelerated inactivation of the channel, Genetic testing, -Serial single-gene testing or gene panel, ',
# ...

# %%
column_names = ['empty','Genetics','Clinical findings/Dysmorphic features','Etiology', 'Pathogenesis','Others']
df = pd.DataFrame(information_final, columns=column_names)
df.drop('empty', axis=1, inplace=True)
df
# Out:
#                                             Genetics  \
# 0  -Most common SCN5A (3p21; 15-30%), also 22 oth...
# 1  -Deletion of ~3Mb on 22q11.2; NAHR, -AD, 90-95...
# 2  -JAG1 (20p12, 95% of cases) and NOTCH2 (1p13-p...
#
#                Clinical findings/Dysmorphic features  \
# 0  -ST-segment abnormalities in leads V1-V3 on el...
# 1  -Congenital heart disease (74% of individuals;...
# 2  -Bile duct paucity  Cholestasis (stop of bile ...
#
#                                             Etiology  \
# 0  -Prevalence of the disease in endemic areas is...
# 1                               -Prevalence 1:3000,
# 2                                        -1:70,000,
#
#                                         Pathogenesis  \
# 0  -SCN5A encodes the α-subunit of the cardiac so...
# 1  -Deleted region is flanked by low copy number ...
# 2  -Truncated JAG1 unable to bind to the cell mem...
#
#                                               Others
# ...
